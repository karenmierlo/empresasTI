# %%
import pandas as pd
url_or_file='https://docs.google.com/spreadsheets/d/e/2PACX-1vQrGR2RwQBQAbt3Mzu0UbgKMGSY1hxXtt8rV1fcLzrwjRy2KBDUaSOoT5EKt-j0t6cxZ0KIz-4O0ZVf/pub?gid=891049362&single=true&output=csv'
colunas=[0,1]
df = pd.read_csv(url_or_file, header=0,usecols=colunas)

# %%
valor=[]
for i in range(0,217):
    valor.append(i)

df.insert(1, 'coluna', valor)
display(df)
# Out:
#     Carimbo de data/hora  coluna  \
# 0    29/08/2022 22:16:01       0
# 1    29/08/2022 22:17:13       1
# 2    29/08/2022 22:18:05       2
# 3    29/08/2022 22:18:23       3
# 4    29/08/2022 22:18:32       4
# ..                   ...     ...
# 212  01/09/2022 21:38:07     212
# 213  01/09/2022 21:38:45     213
# 214  01/09/2022 21:42:21     214
# 215  01/09/2022 21:42:25     215
# 216  01/09/2022 22:00:09     216
#
#     1) Você é aluno de qual curso do Programa Entra21?
# 0                                     Análise de Dados
# 1                                     Análise de Dados
# 2                                     Análise de Dados
# 3                                     Análise de Dados
# 4                                     Análise de Dados
# ..                                                 ...
# 212                                               Java
# 213                                               Java
# 214                                               Java
# 215                                               Java
# 216                                      Suporte de TI
#
# [217 rows x 3 columns]
