# %%
import pandas as pd

# %% [markdown]
# Importando planilha google docs

# %%
url_or_file='https://docs.google.com/spreadsheets/d/e/2PACX-1vQrGR2RwQBQAbt3Mzu0UbgKMGSY1hxXtt8rV1fcLzrwjRy2KBDUaSOoT5EKt-j0t6cxZ0KIz-4O0ZVf/pub?gid=891049362&single=true&output=csv'

# %% [markdown]
# Criando Dataframe vazio onde recebera atravez do laço for, todas as perguntas com suas respostas das (14) colunas.

# %%
df=pd.DataFrame()
df['Carimbo_de_data_hora']=''
df['Answer']=''
df['Question']=''
df['Questionid']=''

# %%
# # aqui estamos limpando nomes de colunas que vinham com espaço e charcter / 
# df.columns = [c.replace(' ', '_') for c in dfok.columns]
# df.columns = [c.replace('/', '_') for c in dfok.columns]

# %% [markdown]
# No laço for abaixo percorremos todas as colunas do CSV adicionando dm df_coluna_by_coluna

# %%
for i in range(1,14):
    colunas=[0,i]
    df_coluna_by_coluna = pd.read_csv(url_or_file, header=0,usecols=colunas)    
    pergunta=df_coluna_by_coluna.columns[1]     
    df_coluna_by_coluna = df_coluna_by_coluna.rename(columns={ pergunta : 'Answer'})    
    df_coluna_by_coluna['Question']=pergunta
    df_coluna_by_coluna['Questionid']=i        
    
    df = (pd.concat([df, df_coluna_by_coluna],ignore_index = True))
    df['Carimbo_de_data_hora']= (pd.to_datetime(df['Carimbo_de_data_hora']))
    df['Questionid']=(pd.to_numeric(df['Questionid']))

print(len(df))


#print(dfok[0:1100])
# dfok1 = dfok[0:1085]
# inicio=(8*216)
# fim=(inicio+1)
# dfok1 = dfok[inicio:fim]
# Out:
# 2821

# %%
display(df)
# Out:
#      Carimbo_de_data_hora                    Answer  \
# 0     2022-08-29 22:16:01          Análise de Dados
# 1     2022-08-29 22:17:13          Análise de Dados
# 2     2022-08-29 22:18:05          Análise de Dados
# 3     2022-08-29 22:18:23          Análise de Dados
# 4     2022-08-29 22:18:32          Análise de Dados
# ...                   ...                       ...
# 2816  2022-01-09 21:38:07                  Espanhol
# 2817  2022-01-09 21:38:45                    Inglês
# 2818  2022-01-09 21:42:21           Inglês, Japonês
# 2819  2022-01-09 21:42:25  Nenhuma das alternativas
# 2820  2022-01-09 22:00:09                    Inglês
#
#                                                Question  Questionid
# 0     1) Você é aluno de qual curso do Programa Entr...           1
# 1     1) Você é aluno de qual curso do Programa Entr...           1
# 2     1) Você é aluno de qual curso do Programa Entr...           1
# 3     1) Você é aluno de qual curso do Programa Entr...           1
# 4     1) Você é aluno de qual curso do Programa Entr...           1
# ...                                                 ...         ...
# 2816  13) Qual (is) o(s) outro(s) idioma(s) você pos...          13
# 2817  13) Qual (is) o(s) outro(s) idioma(s) você pos...          13
# 2818  13) Qual (is) o(s) outro(s) idioma(s) você pos...          13
# 2819  13) Qual (is) o(s) outro(s) idioma(s) você pos...          13
# 2820  13) Qual (is) o(s) outro(s) idioma(s) você pos...          13
#
# [2821 rows x 4 columns]

# %% [markdown]
# Abaixo criamos uma codificação para os nomes de empresas e outros detalhes.
# questionid = 8
# questionid = 9

# %%
def verifica(base8,empresa):
    ret='None'
    for a,b in base8.items():
        if (a == empresa):
            ret = b                        
            
    return ret

        
base8 = {
'Senior Sistemas' : 'Empresa1',
'Philips':'Empresa2',
'Ailos' : 'Empresa3',
'Capgemini' : 'Empresa4',
'Ambev Tech' : 'Empresa5',
'Warren' : 'Empresa6',
'DataInfo' : 'Empresa7',
'Farmácias App' : 'Empresa8',
'Havan Labs' : 'Empresa9',
'T-Systems' : 'Empresa10',
'Unifique' : 'Empresa11'
}

# base8 = {
# 'Empresa1' : 'Senior Sistemas',
# 'Empresa2':  'Philips',
# 'Empresa3' : 'Ailos',
# 'Empresa4' : 'Capgemini',
# 'Empresa5' : 'Ambev Tech',
# 'Empresa6' : 'Warren',
# 'Empresa7' : 'DataInfo',
# 'Empresa8' : 'Farmácias App',
# 'Empresa9' : 'Havan Labs',
# 'Empresa10' : 'T-Systems',
# 'Empresa11' : 'Unifique'
# }

#Ailos, Ambev Tech, Capgemini,
#DataInfo, Farmácias App, Havan Labs, 
#Philips, Senior Sistemas, 
#T-Systems, Unifique, Warren

def verifica_b9(base9,empresa):
    ret='None'
    for a,b in base9.items():
        if (a == empresa):
            ret = b                        
            
    return ret

base9 = {
'Empresa1' : 'Empresa1',
'Empresa2' : 'Empresa2',
'Empresa3' : 'Empresa3',
'Empresa4' : 'Empresa4',
'Empresa5' : 'Empresa5',
'Empresa6' : 'Empresa6',
'Empresa7' : 'Empresa7',
'Empresa8' : 'Empresa8',
'Empresa9' : 'Empresa9',
'Empresa10' : 'Empresa10',
'Empresa11' : 'Empresa11'
}

# %%
#dataframe New Serializer
dfns=pd.DataFrame()

crb=[]
qst=[]
qid=[]
ans=[]
ans_code=[]

for index,row in df.iterrows():            
    for answerseparada in (list(str.split(row.Answer,sep=','))): 
        crb.append(row.Carimbo_de_data_hora)
        qst.append(row.Question)
        qid.append(row.Questionid)
        ans.append(answerseparada)
        if (row.Questionid == 8):
            ans_code.append(verifica(base8,answerseparada))
        elif (row.Questionid == 9):
            ans_code.append(verifica_b9(base9,answerseparada))
        else:
            ans_code.append(answerseparada)        
                
        
dfns['Carimbo_de_data_hora'] = crb
dfns['Question'] = qst
dfns['Questionid'] = qid
dfns['Answer'] = ans
dfns['AnswerCode'] = ans_code


print(dfns.shape)
# Out:
# (4336, 5)

# %%
display(dfns)
# Out:
#      Carimbo_de_data_hora                                           Question  \
# 0     2022-08-29 22:16:01  1) Você é aluno de qual curso do Programa Entr...
# 1     2022-08-29 22:17:13  1) Você é aluno de qual curso do Programa Entr...
# 2     2022-08-29 22:18:05  1) Você é aluno de qual curso do Programa Entr...
# 3     2022-08-29 22:18:23  1) Você é aluno de qual curso do Programa Entr...
# 4     2022-08-29 22:18:32  1) Você é aluno de qual curso do Programa Entr...
# ...                   ...                                                ...
# 4331  2022-01-09 21:38:45  13) Qual (is) o(s) outro(s) idioma(s) você pos...
# 4332  2022-01-09 21:42:21  13) Qual (is) o(s) outro(s) idioma(s) você pos...
# 4333  2022-01-09 21:42:21  13) Qual (is) o(s) outro(s) idioma(s) você pos...
# 4334  2022-01-09 21:42:25  13) Qual (is) o(s) outro(s) idioma(s) você pos...
# 4335  2022-01-09 22:00:09  13) Qual (is) o(s) outro(s) idioma(s) você pos...
#
#       Questionid                    Answer                AnswerCode
# 0              1          Análise de Dados          Análise de Dados
# 1              1          Análise de Dados          Análise de Dados
# 2              1          Análise de Dados          Análise de Dados
# 3              1          Análise de Dados          Análise de Dados
# 4              1          Análise de Dados          Análise de Dados
# ...          ...                       ...                       ...
# 4331          13                    Inglês                    Inglês
# 4332          13                    Inglês                    Inglês
# 4333          13                   Japonês                   Japonês
# 4334          13  Nenhuma das alternativas  Nenhuma das alternativas
# 4335          13                    Inglês                    Inglês
#
# [4336 rows x 5 columns]

# %%
import mysql.connector

# %%
cnx = mysql.connector.connect(
    host = '3.89.36.150',
    user = 'e2122g3',
    password = 'e2122g3@16@ago',
    database = 'e2122g3'
    )

cur = cnx.cursor()

cur.execute("""
    DROP TABLE IF EXISTS PERGUNTAS_TCC; 
""")

cur.execute("""    
    CREATE TABLE PERGUNTAS_TCC(
            PERGUNTAS_CARIMBO DATE NOT NULL,
            PERGUNTAS_ID_RESPOSTA INTEGER,
            PERGUNTAS_NOME TEXT NOT NULL,
            PERGUNTAS_RESPOSTA TEXT NOT NULL
    );
""")

# %%
divisoes = int((len(dfns))/1000+1)

print(divisoes)

def insere_valores(inicio,fim):
    print(inicio,fim)
    values = []
    for index,row in dfns[inicio:fim].iterrows():    
        for xresp in (list(str.split(row.Answer,sep=','))):
            CARIMBO = row.Carimbo_de_data_hora
            IDRESPOSTA = row.Questionid
            PERGUNTA = row.Question
            RESPOSTA = xresp 
            
            values.append((CARIMBO,IDRESPOSTA,PERGUNTA,RESPOSTA))           
            print((inicio,fim,CARIMBO,IDRESPOSTA,PERGUNTA,RESPOSTA))

    insert_values = "".join(str(values).strip('[]'))
    sql=(f"INSERT INTO PERGUNTAS_TCC (PERGUNTAS_CARIMBO,PERGUNTAS_ID_RESPOSTA,PERGUNTAS_NOME,PERGUNTAS_RESPOSTA) VALUES {insert_values}")

    
    cur.execute(sql)
    cnx.commit()
# Out:
# 5

# %%
divisoes = int((len(dfns))/1000+1)

print(divisoes)

total = int(len(dfns))
passo = int(len(dfns)/divisoes)
saldo = total

x, inicio, fim = 0, 0, 0
lista = []

while saldo > 0:   

    fim = fim+passo
    print(f'saldo: {saldo} passo: {passo}' )

    if saldo < passo:
        fim = inicio + (saldo-1)      
        
        # lista.append((inicio, inicio+saldo))
    else:
        fim = inicio + (passo -1)
        # lista.append((inicio, fim))        

    saldo = saldo-passo
), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Vue.js')
# (0, 866, Timestamp('2022-01-09 08:49:53'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 08:50:03'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'UXI - UX/UI')
# (0, 866, Timestamp('2022-01-09 08:50:56'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Vue.js')
# (0, 866, Timestamp('2022-01-09 08:52:27'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 08:55:26'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 08:58:33'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 09:01:20'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Vue.js')
# (0, 866, Timestamp('2022-01-09 09:04:05'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Android')
# (0, 866, Timestamp('2022-01-09 09:07:53'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 09:12:37'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'UXI - UX/UI')
# (0, 866, Timestamp('2022-01-09 09:15:06'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 09:23:05'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Vue.js')
# (0, 866, Timestamp('2022-01-09 09:23:35'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 09:26:03'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'UXI - UX/UI')
# (0, 866, Timestamp('2022-01-09 09:26:12'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Office 365')
# (0, 866, Timestamp('2022-01-09 09:26:38'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Vue.js')
# (0, 866, Timestamp('2022-01-09 09:30:28'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Vue.js')
# (0, 866, Timestamp('2022-01-09 09:35:46'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 09:37:03'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Vue.js')
# (0, 866, Timestamp('2022-01-09 09:49:37'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 10:05:17'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 10:11:16'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 10:11:51'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 10:21:13'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 10:21:24'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Flutter')
# (0, 866, Timestamp('2022-01-09 10:22:58'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 10:25:59'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 10:30:14'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 10:42:46'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 10:46:38'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 10:50:41'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 10:53:24'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 10:56:14'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 10:58:52'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 11:00:24'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 11:01:06'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Android')
# (0, 866, Timestamp('2022-01-09 11:01:32'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 11:16:10'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 11:29:04'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'PHP')
# (0, 866, Timestamp('2022-01-09 11:32:21'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 11:34:30'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 11:37:52'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 11:38:05'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 11:40:46'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 11:41:27'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Flutter')
# (0, 866, Timestamp('2022-01-09 11:43:04'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 11:43:12'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 11:43:52'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 11:48:28'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 11:50:13'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Banco de dados')
# (0, 866, Timestamp('2022-01-09 11:53:12'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 11:55:05'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 11:55:23'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'PHP')
# (0, 866, Timestamp('2022-01-09 11:55:30'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 11:55:56'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Flutter')
# (0, 866, Timestamp('2022-01-09 11:56:32'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 11:59:16'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Analista de Mídias Digitais')
# (0, 866, Timestamp('2022-01-09 12:04:14'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 12:10:17'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 12:10:25'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 12:12:14'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 12:16:49'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 12:19:15'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 12:21:36'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 12:40:44'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 12:52:13'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 12:55:40'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 12:59:40'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 13:01:21'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 13:02:56'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Python')
# (0, 866, Timestamp('2022-01-09 13:03:22'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 13:03:25'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 13:18:31'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Office 365')
# (0, 866, Timestamp('2022-01-09 13:21:19'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13:25:32'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13:28:32'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 13:29:13'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13:30:42'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Flutter')
# (0, 866, Timestamp('2022-01-09 13:32:44'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'PHP')
# (0, 866, Timestamp('2022-01-09 13:36:14'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13:38:24'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'Java')
# (0, 866, Timestamp('2022-01-09 13:39:44'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13:47:50'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13:48:01'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13:48:11'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13:48:17'), 1, '1) Você é aluno de qual curso do Programa Entra21?', 'C#')
# (0, 866, Timestamp('2022-01-09 13
), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:48:11'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:48:11'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Espanhol')
# (3468, 4335, Timestamp('2022-01-09 13:48:17'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:48:28'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:48:31'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:48:35'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:48:35'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Alemão')
# (3468, 4335, Timestamp('2022-01-09 13:48:46'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 13:49:21'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:49:31'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:49:45'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:49:52'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:50:14'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 13:51:34'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:54:56'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:54:56'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Espanhol')
# (3468, 4335, Timestamp('2022-01-09 13:54:56'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Francês')
# (3468, 4335, Timestamp('2022-01-09 13:54:56'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' japones/russo')
# (3468, 4335, Timestamp('2022-01-09 13:55:49'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:55:49'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Intermediário ')
# (3468, 4335, Timestamp('2022-01-09 13:56:14'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:56:16'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:56:16'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Iniciante ')
# (3468, 4335, Timestamp('2022-01-09 13:56:27'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 13:56:54'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 14:06:41'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 14:15:22'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 14:18:36'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 14:37:13'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 15:26:54'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 15:26:54'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Espanhol')
# (3468, 4335, Timestamp('2022-01-09 15:26:54'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Português (Sou estrangeiro)')
# (3468, 4335, Timestamp('2022-01-09 15:33:46'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 15:54:57'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 15:54:57'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Italiano')
# (3468, 4335, Timestamp('2022-01-09 16:44:42'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 16:57:18'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 16:57:19'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 17:00:19'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 17:00:53'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 17:36:46'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 18:09:33'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 18:29:01'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 18:35:48'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 18:41:31'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 18:41:31'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Latim ')
# (3468, 4335, Timestamp('2022-01-09 18:46:52'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 19:00:31'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 20:39:43'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 20:41:43'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 20:42:39'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 20:43:00'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 20:47:49'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 20:48:50'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 20:56:01'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 20:56:01'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Espanhol')
# (3468, 4335, Timestamp('2022-01-09 21:08:52'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 21:08:52'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Espanhol')
# (3468, 4335, Timestamp('2022-01-09 21:11:45'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 21:14:49'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 21:17:58'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 21:17:58'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Espanhol')
# (3468, 4335, Timestamp('2022-01-09 21:22:47'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')
# (3468, 4335, Timestamp('2022-01-09 21:23:54'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 21:38:07'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Espanhol')
# (3468, 4335, Timestamp('2022-01-09 21:38:45'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 21:42:21'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Inglês')
# (3468, 4335, Timestamp('2022-01-09 21:42:21'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', ' Japonês')
# (3468, 4335, Timestamp('2022-01-09 21:42:25'), 13, '13) Qual (is) o(s) outro(s) idioma(s) você possui conhecimento (nível intermediário/fluente)? Caso queira você poderá selecionar mais de uma opção de resposta:', 'Nenhuma das alternativas')

# %%
cur = cnx.cursor()
cur.execute("""
    "SELECT COUNT(*) FROM PERGUNTAS_TCC"; 
""")

cnx.commit()
